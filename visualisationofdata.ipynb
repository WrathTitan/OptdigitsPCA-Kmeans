# %% [markdown]
# <a href="https://colab.research.google.com/github/WrathTitan/OptdigitsPCA-Kmeans/blob/master/visualisationofdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
optdigits_df=pd.read_csv('/content/drive/MyDrive/optdigits_csv.xls')
optdigits_df
# Out:
#       input1  input2  input3  input4  ...  input62  input63  input64  class
# 0          0       1       6      15  ...        1        0        0      0
# 1          0       0      10      16  ...        3        0        0      0
# 2          0       0       8      15  ...        0        0        0      7
# 3          0       0       0       3  ...        2        0        0      4
# 4          0       0       5      14  ...        7        0        0      6
# ...      ...     ...     ...     ...  ...      ...      ...      ...    ...
# 5615       0       0       4      10  ...        9        0        0      9
# 5616       0       0       6      16  ...        6        0        0      0
# 5617       0       0       1      11  ...        6        0        0      8
# 5618       0       0       2      10  ...       12        0        0      9
# 5619       0       0      10      14  ...       12        1        0      8
#
# [5620 rows x 65 columns]

# %%
import matplotlib.pyplot as plt

# %%
optdigits_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5620 entries, 0 to 5619
# Data columns (total 65 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   input1   5620 non-null   int64
#  1   input2   5620 non-null   int64
#  2   input3   5620 non-null   int64
#  3   input4   5620 non-null   int64
#  4   input5   5620 non-null   int64
#  5   input6   5620 non-null   int64
#  6   input7   5620 non-null   int64
#  7   input8   5620 non-null   int64
#  8   input9   5620 non-null   int64
#  9   input10  5620 non-null   int64
#  10  input11  5620 non-null   int64
#  11  input12  5620 non-null   int64
#  12  input13  5620 non-null   int64
#  13  input14  5620 non-null   int64
#  14  input15  5620 non-null   int64
#  15  input16  5620 non-null   int64
#  16  input17  5620 non-null   int64
#  17  input18  5620 non-null   int64
#  18  input19  5620 non-null   int64
#  19  input20  5620 non-null   int64
#  20  input21  5620 non-null   int64
# ...

# %%
optdigits_df.describe()
# Out:
#        input1       input2       input3  ...      input63      input64        class
# count  5620.0  5620.000000  5620.000000  ...  5620.000000  5620.000000  5620.000000
# mean      0.0     0.302135     5.393238  ...     2.093594     0.254093     4.495196
# std       0.0     0.879962     4.672719  ...     4.047959     1.418558     2.868131
# min       0.0     0.000000     0.000000  ...     0.000000     0.000000     0.000000
# 25%       0.0     0.000000     1.000000  ...     0.000000     0.000000     2.000000
# 50%       0.0     0.000000     5.000000  ...     0.000000     0.000000     4.000000
# 75%       0.0     0.000000     9.000000  ...     2.000000     0.000000     7.000000
# max       0.0     8.000000    16.000000  ...    16.000000    16.000000     9.000000
#
# [8 rows x 65 columns]

# %%
#trans=optdigits_df.T
import matplotlib.pyplot as plt
b=optdigits_df.describe()
trans=b.T
plt.xlabel('inputs')
plt.ylabel('maximum')
plt.title('maximum of inputs')
print(trans.describe())
trans['max'].plot(kind='bar')
# Out:
#         count       mean        std  ...        50%        75%        max
# count    65.0  65.000000  65.000000  ...  65.000000  65.000000  65.000000
# mean   5620.0   4.904843   3.673705  ...   4.753846   7.769231  13.323077
# std       0.0   4.189976   2.288066  ...   5.031249   6.587795   5.006582
# min    5620.0   0.000000   0.000000  ...   0.000000   0.000000   0.000000
# 25%    5620.0   0.281851   1.046998  ...   0.000000   0.000000  14.000000
# 50%    5620.0   4.495196   4.255952  ...   4.000000   7.000000  16.000000
# 75%    5620.0   9.033808   5.825809  ...  10.000000  15.000000  16.000000
# max    5620.0  11.989680   6.518238  ...  13.000000  16.000000  16.000000
#
# [8 rows x 8 columns]

# %%
#trans=optdigits_df.T
import matplotlib.pyplot as plt
b=optdigits_df.describe()
trans=b.T
plt.xlabel('inputs')
plt.ylabel('mean')
plt.title('mean of inputs')
print(trans.describe())
trans['mean'].plot(kind='bar')
# Out:
#         count       mean        std  ...        50%        75%        max
# count    65.0  65.000000  65.000000  ...  65.000000  65.000000  65.000000
# mean   5620.0   4.904843   3.673705  ...   4.753846   7.769231  13.323077
# std       0.0   4.189976   2.288066  ...   5.031249   6.587795   5.006582
# min    5620.0   0.000000   0.000000  ...   0.000000   0.000000   0.000000
# 25%    5620.0   0.281851   1.046998  ...   0.000000   0.000000  14.000000
# 50%    5620.0   4.495196   4.255952  ...   4.000000   7.000000  16.000000
# 75%    5620.0   9.033808   5.825809  ...  10.000000  15.000000  16.000000
# max    5620.0  11.989680   6.518238  ...  13.000000  16.000000  16.000000
#
# [8 rows x 8 columns]
